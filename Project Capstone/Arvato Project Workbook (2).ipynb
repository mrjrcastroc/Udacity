# %% [markdown]
# # Capstone Project: Create a Customer Segmentation Report for Arvato Financial Services
#
# In this project, you will analyze demographics data for customers of a mail-order sales company in Germany, comparing it against demographics information for the general population. You'll use unsupervised learning techniques to perform customer segmentation, identifying the parts of the population that best describe the core customer base of the company. Then, you'll apply what you've learned on a third dataset with demographics information for targets of a marketing campaign for the company, and use a model to predict which individuals are most likely to convert into becoming customers for the company. The data that you will use has been provided by our partners at Bertelsmann Arvato Analytics, and represents a real-life data science task.
#
# The versions of those two datasets used in this project will include many more features and has not been pre-cleaned. You are also free to choose whatever approach you'd like to analyzing the data rather than follow pre-determined steps. In your work on this project, make sure that you carefully document your steps and decisions, since your main deliverable for this project will be a blog post reporting your findings.

# %%
# import libraries here; add more as necessary
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster import hierarchy
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.pipeline import make_pipeline
from sklearn.cluster import KMeans
from sklearn.tree import DecisionTreeClassifier
from sklearn.pipeline import Pipeline
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_validate
from imblearn.under_sampling import RandomUnderSampler

from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier


import warnings

warnings.filterwarnings('ignore')

# magic word for producing visualizations in notebook
# %matplotlib inline

# %%
def treinar_modelo(modelo, X_train, y_train, cv, random_state, n_jobs=-1):
    '''
    Function to train a pipeline and returns the model's metrics
    Inputs
        modelo: model that will be trained
        X_train: x train data
        y_train: y train data
        cv: numbers of cv
        random_state: random state
        n_jobs: number of jobs
    Output:
        Returns a list with the model's metrics
        
    '''
    
    pipeline = Pipeline([modelo])
    resultado_cv = cross_validate(
                            estimator=pipeline, 
                            X=X_train,
                            y=y_train,
                            scoring=['accuracy', 'precision', 'recall', 'f1', 'roc_auc'],
                            cv=cv,
                            n_jobs=-1)

    df_aux = pd.DataFrame(resultado_cv)
    dfar = df_aux.mean()

    return [
            dfar.loc['test_accuracy'], 
            dfar.loc['test_precision'], 
            dfar.loc['test_recall'], 
            dfar.loc['test_f1'], 
            dfar.loc['test_roc_auc']
    ]

# %% [markdown]
# ## Part 0: Get to Know the Data
#
# There are four data files associated with this project:
#
# - `Udacity_AZDIAS_052018.csv`: Demographics data for the general population of Germany; 891 211 persons (rows) x 366 features (columns).
# - `Udacity_CUSTOMERS_052018.csv`: Demographics data for customers of a mail-order company; 191 652 persons (rows) x 369 features (columns).
# - `Udacity_MAILOUT_052018_TRAIN.csv`: Demographics data for individuals who were targets of a marketing campaign; 42 982 persons (rows) x 367 (columns).
# - `Udacity_MAILOUT_052018_TEST.csv`: Demographics data for individuals who were targets of a marketing campaign; 42 833 persons (rows) x 366 (columns).
#
# Each row of the demographics files represents a single person, but also includes information outside of individuals, including information about their household, building, and neighborhood. Use the information from the first two files to figure out how customers ("CUSTOMERS") are similar to or differ from the general population at large ("AZDIAS"), then use your analysis to make predictions on the other two files ("MAILOUT"), predicting which recipients are most likely to become a customer for the mail-order company.
#
# The "CUSTOMERS" file contains three extra columns ('CUSTOMER_GROUP', 'ONLINE_PURCHASE', and 'PRODUCT_GROUP'), which provide broad information about the customers depicted in the file. The original "MAILOUT" file included one additional column, "RESPONSE", which indicated whether or not each recipient became a customer of the company. For the "TRAIN" subset, this column has been retained, but in the "TEST" subset it has been removed; it is against that withheld column that your final predictions will be assessed in the Kaggle competition.
#
# Otherwise, all of the remaining columns are the same between the three data files. For more information about the columns depicted in the files, you can refer to two Excel spreadsheets provided in the workspace. [One of them](./DIAS Information Levels - Attributes 2017.xlsx) is a top-level list of attributes and descriptions, organized by informational category. [The other](./DIAS Attributes - Values 2017.xlsx) is a detailed mapping of data values for each feature in alphabetical order.
#
# In the below cell, we've provided some initial code to load in the first two datasets. Note for all of the `.csv` data files in this project that they're semicolon (`;`) delimited, so an additional argument in the [`read_csv()`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html) call has been included to read in the data properly. Also, considering the size of the datasets, it may take some time for them to load completely.
#
# You'll notice when the data is loaded in that a warning message will immediately pop up. Before you really start digging into the modeling and analysis, you're going to need to perform some cleaning. Take some time to browse the structure of the data and look over the informational spreadsheets to understand the data values. Make some decisions on which features to keep, which features to drop, and if any revisions need to be made on data formats. It'll be a good idea to create a function with pre-processing steps, since you'll need to clean all of the datasets before you work with them.

# %% [markdown]
# ## Data Preparation

# %%
# load in the data
azdias = pd.read_csv('azdias.csv', sep=',')
customers = pd.read_csv('customers.csv', sep=',')
df_atributes = pd.read_excel('DIAS Attributes - Values 2017.xlsx',header = 1)

azdias = azdias.drop('Unnamed: 0', axis=1)
customers = customers.drop('Unnamed: 0', axis=1)

# %% [markdown]
# Como temos uma grande quantidade de colunas, **vamos remover todas as colunas que tenham mais do que 25% de valores missing**

# %%
# Analysing the missing data and getting % Null
df_azdias_columns= pd.DataFrame(azdias.isna().mean()).reset_index()
df_azdias_columns.columns = ['Attribute', '%null']
df_azdias_columns = pd.merge(df_atributes, df_azdias_columns, on='Attribute')
columns = list(df_azdias_columns[df_azdias_columns['%null'] <= 0.25]['Attribute'])

# %%
azdias = azdias[columns].dropna()
customers = customers[columns].dropna()

# %%
# Categorical data
category_columns = ['CAMEO_DEUG_2015', 'CAMEO_DEU_2015', 'OST_WEST_KZ']

# Converting to category data type

azdias[category_columns] = azdias[category_columns].astype('category')
customers[category_columns] = customers[category_columns].astype('category')

# Creating dummies to all categorical features
azdias_treated = pd.get_dummies(azdias)
customers_treated = pd.get_dummies(customers)

# %% [markdown]
# ### Análise Exploratória

# %% [markdown]
# ## Part 1: Customer Segmentation Report
#
# The main bulk of your analysis will come in this part of the project. Here, you should use unsupervised learning techniques to describe the relationship between the demographics of the company's existing customers and the general population of Germany. By the end of this part, you should be able to describe parts of the general population that are more likely to be part of the mail-order company's main customer base, and which parts of the general population are less so.

# %% [markdown]
# ### Dendogram

# %% [markdown]
# A dendrogram is a graphical representation of a hierarchical structure. It is commonly used in cluster analysis to show how individual elements or groups of elements are clustered with each other. Dendrograms are particularly useful in multivariate data analysis, such as in statistics and bioinformatics.

# %%
pca = make_pipeline(StandardScaler(), PCA(n_components=3, random_state=123))
X_reduced = pd.DataFrame(pca.fit_transform(azdias_treated), columns=['pc1', 'pc2','pc3'])
fig, ax = plt.subplots(figsize=(20, 30))
ax.grid(False)
cluster_aglo = hierarchy.linkage(X_reduced.sample(20000), method='ward') 

dend = hierarchy.dendrogram(cluster_aglo)

# %% [markdown]
# ### Elbow Method

# %% [markdown]
# The elbow method is a technique used in cluster analysis to determine the optimal number of clusters in a dataset. The idea behind this method is to observe the variation of the sum of intra-cluster squares concerning the number of clusters. The "elbow" point in the graph of this variation suggests the optimal number of clusters, where adding more clusters does not provide significant gains in reducing intra-cluster variance.

# %%
# Usando o método do cotovelo, também conhecido como Elbow Method

# A classe KElbowVisualizer implementa o método "elbow" para selecionar o número ótimo de clusters para o KMeans.
from sklearn.cluster import KMeans

model = KMeans()

sse = []
list_k = list(range(1, 30))

for k in list_k:
    km = KMeans(n_clusters=k, init='k-means++')
    km.fit(X_reduced.sample(20000))
    sse.append(km.inertia_)
    
# Plot sse against k
plt.figure(figsize=(20, 8))
plt.plot(list_k, sse, '-o')
plt.title('k-means Clustering Elbow Plot - azdias')
plt.xlabel("Number of clusters k")
plt.ylabel("Sum of squared distance")
plt.xticks(list(range(1,30)))
plt.show()

# %% [markdown]
# As we can see in the dendrogram and elbow visualizations below, we will select **7 clusters** to create the model.

# %% [markdown]
# ## Machine Learning Pipeline

# %% [markdown]
# #### Kmeans Model

# %% [markdown]
# The K-Means algorithm is a popular method for clustering data, widely used in machine learning and data mining. Its main purpose is to divide a dataset into k groups (clusters) based on the similarity of elements.

# %% [markdown]
# #### Principal Component Analysis
#
# Principal Component Analysis (PCA) is a statistical technique used for dimensionality reduction in complex datasets. The main goal is to transform a set of correlated variables into a set of uncorrelated variables, known as principal components. These components capture most of the variance present in the original data.

# %% [markdown]
# ### Standard Scaler
#
# The Standard Scaler is a data preprocessing technique used in statistical analysis and machine learning to standardize the features of a dataset. Standardization involves transforming the features so that they have a mean of zero and a standard deviation of one. This means that the data is adjusted to follow a normal distribution with a mean of zero and a standard deviation of one.
#
# The standardization process is important when the features in the dataset have different scales, which can adversely affect scale-sensitive machine learning algorithms. By applying the Standard Scaler, features are rescaled so that they all have the same scale, making the data comparable.

# %%
pca_components = pipeline.named_steps['pca']
kmeans = pipeline.named_steps['kmeans']
transformer =  pipeline.named_steps['standard_scaler']

# %%
pipeline = Pipeline([
    ('standard_scaler', StandardScaler()),
    ('pca', PCA(n_components=3, random_state = 1)),
    ('kmeans', KMeans(n_clusters=7, random_state=30, init = 'k-means++'))
]
)
pipeline.fit(azdias_treated)
# Out:
# Pipeline(steps=[('standard_scaler', StandardScaler()),
#                 ('pca', PCA(n_components=3, random_state=1)),
#                 ('kmeans', KMeans(n_clusters=7, random_state=30))])

# %%
# Predict cluster using population data
cluster = pipeline.predict(azdias_treated)

# %% [markdown]
# ### Surrogate Tree Tecnichque
#
# The Surrogate Tree method involves training a decision tree to understand the most important variables within the clusters

# %%
clf = DecisionTreeClassifier(random_state=30)
clf.fit(azdias_treated, cluster)
# Out:
# DecisionTreeClassifier(random_state=30)

# %%
top_features = pd.Series(clf.feature_importances_, index=azdias_treated.columns).sort_values(ascending=False).head(15).index.tolist()

# %%
fig, ax = plt.subplots(figsize=(20, 10))

sns.heatmap(azdias_treated.groupby(pipeline.named_steps['kmeans'].labels_).mean()[top_features].round(2), ax=ax, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Visualization of Cluster Populations

# %%
#columns_ = list(azdias_treated.drop('Cluster', axis=1))
customers_treated = customers_treated[columns_]

# %%
azdias_treated['Cluster'] = pipeline.predict(azdias_treated[columns_]) +1 
customers_treated['Cluster'] = pipeline.predict(customers_treated) +1

# %%
customer_clustered = customers_treated['Cluster'].value_counts().sort_index()
polulation_clustered = azdias_treated['Cluster'].value_counts().sort_index()

# %%
Analisando os clusters mais propensos

# %%
clusters = pd.concat([polulation_clustered, customer_clustered], axis=1)
clusters.columns = ['Population', 'Customer']
clusters['% Population / Customer'] = clusters['Customer'] / clusters['Population'] * 100
clusters
# Out:
#    Population  Customer  % Population / Customer
# 1      151321     18116                11.971901
# 2      161906     57101                35.267995
# 3       12353       664                 5.375212
# 4      105983      4276                 4.034609
# 5       79099      8997                11.374354
# 6      108383      8003                 7.383999
# 7       78814     26085                33.096912

# %% [markdown]
# Abaixo podemos ver a distibuição dos 7 clusters em relação a base de dados. Conseguimos notar que os clusters que possuem a maior concentração de clientes são os clusters 1, 2 e 7.
#
# O Perfil desses clusters está segmentado dessa forma
#
# | ---- | Cluster 1 |Cluster 2 | Cluster 7 |
# |---|---|---|---|
# | Transaction activity TOTAL POOL in the last 24  | 1 |  2 | 1 |
# | Total POOL in the last 24 months   | 5 |  3 | 5 |
# | Density of inhabitants per square kilometer | 5 |  2 | 2 |
# | Estimated household net income | 3 |  3 | 4 |
# | Share of Mercedes/BMW (reffered to the county average)  | 3 |  3 | 2 |
# | Share of car owners between 46 and 60 within the PLZ8  | 3 |  3 | 5 |
# | Share of BMW & Mercedes Benz within the PLZ8	  | 3 |  3 | 4 |
# | Share of cars with a greater max speed than 210 km/h within the PLZ8  | 15|  36 | 20 |
# | Share of cars up to 60 KW engine power - PLZ8	  | 4 |  10 | 9 |
# | Share of cars with an engine power more than 120 KW - PLZ8 | 3 |  4 | 4 |
# | Single low-income earners of younger age | 1 |  1 | 1 |
# | Number of 1-2 family houses in the PLZ8 | 2 |  3 | 2 |
# | Most common building-type within the PLZ8  | 1 |  1 | 1 |

# %%
fig, ax = plt.subplots(figsize=(16,6))
plt.title('Cluster Distribution: Population x Customers')
visualization_population = ax.bar(clusters.index, clusters['Population'], bottom=0)
visualization_customer = ax.bar(clusters.index, clusters['Customer'], bottom=0)
ax.legend((visualization_population[0], visualization_customer[0]), ('Population', 'Customers'))
plt.show()

# %%
customers_treated_agg[customers_treated_agg['Cluster'].isin([1,2,7])].T.reset_index()
# Out:
#                    index     0     1     6
# 0                Cluster   1.0   2.0   7.0
# 1      D19_GESAMT_ANZ_24   1.0   2.0   1.0
# 2               EWDICHTE   5.0   3.0   5.0
# 3     HH_EINKOMMEN_SCORE   5.0   2.0   2.0
# 4        KBA05_KRSHERST1   3.0   3.0   4.0
# 5   KBA13_ALTERHALTER_60   3.0   3.0   2.0
# 6   KBA13_HERST_BMW_BENZ   3.0   3.0   5.0
# 7          KBA13_KMH_211   3.0   3.0   4.0
# 8          KBA13_KW_0_60   3.0   3.0   2.0
# 9           KBA13_KW_121   3.0   3.0   4.0
# 10   LP_LEBENSPHASE_FEIN  15.0  36.0  20.0
# 11        LP_STATUS_FEIN   4.0  10.0   9.0
# 12            MOBI_REGIO   3.0   4.0   4.0
# 13         OST_WEST_KZ_W   1.0   1.0   1.0
# 14            PLZ8_ANTG1   2.0   3.0   2.0
# 15           PLZ8_BAUMAX   1.0   1.0   1.0

# %% [markdown]
# ## Part 2: Supervised Learning Model
#
# Now that you've found which parts of the population are more likely to be customers of the mail-order company, it's time to build a prediction model. Each of the rows in the "MAILOUT" data files represents an individual that was targeted for a mailout campaign. Ideally, we should be able to use the demographic information from each individual to decide whether or not it will be worth it to include that person in the campaign.
#
# The "MAILOUT" data has been split into two approximately equal parts, each with almost 43 000 data rows. In this part, you can verify your model with the "TRAIN" partition, which includes a column, "RESPONSE", that states whether or not a person became a customer of the company following the campaign. In the next part, you'll need to create predictions on the "TEST" partition, where the "RESPONSE" column has been withheld.

# %%
# Reading train and test data
mailout_train = pd.read_csv('Udacity_MAILOUT_052018_TRAIN.csv', sep=';').drop('Unnamed: 0', axis=1)
mailout_teste = pd.read_csv('Udacity_MAILOUT_052018_TRAIN.csv', sep=';').drop('Unnamed: 0', axis=1)

# %% [markdown]
# ### Data Preparation

# %%
# Getting all the columns with <= 25 % missing data
mailout_columns = pd.DataFrame(mailout_train.isna().sum() / mailout_train.shape[0]).reset_index()
mailout_columns.columns = ['column', '%null']
columns = list(mailout_columns[mailout_columns['%null'] <= 0.25]['column'].values)

# %% [markdown]
# #### Removing NA values from our data

# %%
mailout_train = mailout_train[columns].dropna()

# %% [markdown]
# #### Adjusting data type from categorical data

# %%
mailout_train_categorical = mailout_train.select_dtypes('object').columns
mailout_train['EINGEFUEGT_AM'] = pd.to_datetime(mailout_train['EINGEFUEGT_AM'], format='%Y-%m-%d ').dt.year
mailout_train[mailout_train_categorical] = mailout_train[mailout_train_categorical].astype('category')
mailout_train_treated = pd.get_dummies(mailout_train)

# %%
mailout_teste['EINGEFUEGT_AM'] = pd.to_datetime(mailout_teste['EINGEFUEGT_AM'], format='%Y-%m-%d ').dt.year
mailout_teste[mailout_train_categorical] = mailout_teste[mailout_train_categorical].astype('category')
mailout_teste = pd.get_dummies(mailout_train)

# %% [markdown]
# #### Getting X and Y data

# %%
X_train = mailout_train_treated.drop('RESPONSE', axis=1)
Y_train = mailout_train_treated.RESPONSE

# %%
X_test = mailout_teste.drop('RESPONSE', axis=1)
Y_test = mailout_teste.RESPONSE

# %% [markdown]
# We have a completely unbalanced database with a distribution of 98.7% to 1.3%. If we train the model without balancing, it will only be able to make accurate predictions for one class.
#
# Because of this, we'll need to balance the classes to achieve good results for both. To do this, we'll employ the randomized under-sampling technique.

# %%
Y_train.value_counts(normalize= True) * 100
# Out:
# 0    98.686136
# 1     1.313864
# Name: RESPONSE, dtype: float64

# %% [markdown]
# #### Under-sampling

# %%
rus = RandomUnderSampler(replacement=True)
X_rus, y_rus = rus.fit_resample(X_train, Y_train)

# %% [markdown]
# ## Data Modeling

# %% [markdown]
# With our data prepared, we will proceed to train the following models: DecisionTreeClassifier, RandomForestClassifier, GradientBoostingClassifier, XGBClassifier, LGBMClassifier, and CatBoostClassifier. We will evaluate which model demonstrates better performance in predicting whether or not a person became a customer of the company following the campaign.

# %% [markdown]
# #### Machine learning Pipeline

# %%
random_state = 142
modelos_arvores = [
    ('decision_tree', DecisionTreeClassifier(random_state=random_state)),
    ('random_forest', RandomForestClassifier(random_state=random_state)),
    ('gb', GradientBoostingClassifier(random_state=random_state)),
    ('xgb', XGBClassifier(random_state=random_state)),
    ('lgbm', LGBMClassifier(random_state=random_state)),
    ('catboost', CatBoostClassifier(random_state=random_state))
]


df_resultados = pd.DataFrame(columns=['acuracidade', 'precision', 'recall', 'f1', 'roc_auc'])

# %% [markdown]
# #### Training Model

# %%
# %%time
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=random_state)


for model in modelos_arvores:
    model_name = model[0]
    print(f'Treinando {model_name} ...', end=' ')
    aux = treinar_modelo(model, X_rus, y_rus, skf, random_state)
    df_resultados.loc[model_name] = aux
    print('OK')
# Out:
# Treinando decision_tree ... OK
# Treinando random_forest ... OK
# Treinando gb ... OK
# Treinando xgb ... OK
# Treinando lgbm ... OK
# Treinando catboost ... OK
# Wall time: 1min 13s

# %% [markdown]
# #### Results
#
# We can observe that after training the models, the CatBoost model exhibited the best performance in identifying whether or not a person became a customer of the company following the campaign. Therefore, we will select this model.

# %%
df_resultados
# Out:
#                acuracidade  precision    recall        f1   roc_auc
# decision_tree     0.655467   0.665327  0.626740  0.644629  0.655378
# random_forest     0.683829   0.697134  0.655511  0.674693  0.742677
# gb                0.744734   0.723464  0.792674  0.756285  0.783322
# xgb               0.731814   0.730265  0.738495  0.732814  0.786134
# lgbm              0.762874   0.744503  0.803130  0.772149  0.797234
# catboost          0.771931   0.739317  0.841891  0.787148  0.796654

# %%
# Melhor modelo foi o Catboost, logo:

best_model = Pipeline([modelos_arvores[-1]])
best_model.fit(X_train, Y_train)
# Out:
# Learning rate set to 0.04363
# 0:	learn: 0.6052013	total: 53.9ms	remaining: 53.8s
# 1:	learn: 0.5297071	total: 102ms	remaining: 50.7s
# 2:	learn: 0.4645789	total: 150ms	remaining: 49.7s
# 3:	learn: 0.4086539	total: 212ms	remaining: 52.7s
# 4:	learn: 0.3611361	total: 275ms	remaining: 54.7s
# 5:	learn: 0.3208782	total: 323ms	remaining: 53.5s
# 6:	learn: 0.2864808	total: 367ms	remaining: 52.1s
# 7:	learn: 0.2570533	total: 428ms	remaining: 53.1s
# 8:	learn: 0.2316893	total: 497ms	remaining: 54.7s
# 9:	learn: 0.2101539	total: 557ms	remaining: 55.2s
# 10:	learn: 0.1918111	total: 606ms	remaining: 54.5s
# 11:	learn: 0.1759238	total: 676ms	remaining: 55.7s
# 12:	learn: 0.1623440	total: 739ms	remaining: 56.1s
# 13:	learn: 0.1506797	total: 802ms	remaining: 56.5s
# 14:	learn: 0.1406433	total: 858ms	remaining: 56.3s
# 15:	learn: 0.1309917	total: 926ms	remaining: 56.9s
# 16:	learn: 0.1234467	total: 982ms	remaining: 56.8s
# 17:	learn: 0.1169428	total: 1.04s	remaining: 56.8s
# 18:	learn: 0.1113182	total: 1.09s	remaining: 56.3s
# 19:	learn: 0.1062575	total: 1.15s	remaining: 56.2s
# 20:	learn: 0.1019792	total: 1.21s	remaining: 56.3s
# 735:	learn: 0.0280746	total: 1m	remaining: 21.6s
# 736:	learn: 0.0280398	total: 1m	remaining: 21.5s
# 737:	learn: 0.0279857	total: 1m	remaining: 21.4s
# 738:	learn: 0.0279677	total: 1m	remaining: 21.4s
# 739:	learn: 0.0279481	total: 1m	remaining: 21.3s
# 740:	learn: 0.0279186	total: 1m	remaining: 21.2s
# 741:	learn: 0.0278752	total: 1m	remaining: 21.1s
# 742:	learn: 0.0278552	total: 1m	remaining: 21s
# 743:	learn: 0.0278190	total: 1m	remaining: 21s
# 744:	learn: 0.0277879	total: 1m	remaining: 20.9s
# 745:	learn: 0.0277830	total: 1m 1s	remaining: 20.8s
# 746:	learn: 0.0277444	total: 1m 1s	remaining: 20.7s
# 747:	learn: 0.0277259	total: 1m 1s	remaining: 20.6s
# 748:	learn: 0.0277123	total: 1m 1s	remaining: 20.5s
# 749:	learn: 0.0276893	total: 1m 1s	remaining: 20.4s
# 750:	learn: 0.0276710	total: 1m 1s	remaining: 20.4s
# 751:	learn: 0.0276483	total: 1m 1s	remaining: 20.3s
# 752:	learn: 0.0276284	total: 1m 1s	remaining: 20.2s
# 753:	learn: 0.0275870	total: 1m 1s	remaining: 20.1s
# 754:	learn: 0.0275425	total: 1m 1s	remaining: 20s
# 755:	learn: 0.0274740	total: 1m 1s	remaining: 19.9s
# 756:	learn: 0.0274062	total: 1m 1s	remaining: 19.9s
# 757:	learn: 0.0273722	total: 1m 1s	remaining: 19.8s
# 758:	learn: 0.0273606	total: 1m 2s	remaining: 19.7s
# 759:	learn: 0.0273440	total: 1m 2s	remaining: 19.6s
# 760:	learn: 0.0272946	total: 1m 2s	remaining: 19.5s
# 761:	learn: 0.0272621	total: 1m 2s	remaining: 19.5s
# 762:	learn: 0.0272312	total: 1m 2s	remaining: 19.4s
# 763:	learn: 0.0272030	total: 1m 2s	remaining: 19.3s
# 764:	learn: 0.0271731	total: 1m 2s	remaining: 19.2s
# 765:	learn: 0.0271416	total: 1m 2s	remaining: 19.1s
# 766:	learn: 0.0271166	total: 1m 2s	remaining: 19.1s
# 767:	learn: 0.0270686	total: 1m 2s	remaining: 19s
# 768:	learn: 0.0270522	total: 1m 2s	remaining: 18.9s
# 769:	learn: 0.0269954	total: 1m 2s	remaining: 18.8s
# 770:	learn: 0.0269715	total: 1m 3s	remaining: 18.7s
# 771:	learn: 0.0269318	total: 1m 3s	remaining: 18.7s
# 772:	learn: 0.0269141	total: 1m 3s	remaining: 18.6s
# 773:	learn: 0.0268957	total: 1m 3s	remaining: 18.5s
# 774:	learn: 0.0268733	total: 1m 3s	remaining: 18.4s
# 775:	learn: 0.0268371	total: 1m 3s	remaining: 18.3s
# 776:	learn: 0.0268150	total: 1m 3s	remaining: 18.2s
# 777:	learn: 0.0267387	total: 1m 3s	remaining: 18.1s
# 778:	learn: 0.0267261	total: 1m 3s	remaining: 18.1s
# 779:	learn: 0.0267092	total: 1m 3s	remaining: 18s
# 780:	learn: 0.0266780	total: 1m 3s	remaining: 17.9s
# 781:	learn: 0.0266555	total: 1m 3s	remaining: 17.8s
# 782:	learn: 0.0266329	total: 1m 4s	remaining: 17.7s
# 783:	learn: 0.0265683	total: 1m 4s	remaining: 17.7s
# 784:	learn: 0.0265434	total: 1m 4s	remaining: 17.6s
# 785:	learn: 0.0265317	total: 1m 4s	remaining: 17.5s
# 786:	learn: 0.0265160	total: 1m 4s	remaining: 17.4s
# 787:	learn: 0.0264948	total: 1m 4s	remaining: 17.3s
# 788:	learn: 0.0264681	total: 1m 4s	remaining: 17.3s
# 789:	learn: 0.0264491	total: 1m 4s	remaining: 17.2s
# 790:	learn: 0.0264114	total: 1m 4s	remaining: 17.1s
# 791:	learn: 0.0263696	total: 1m 4s	remaining: 17s
# 792:	learn: 0.0263222	total: 1m 4s	remaining: 16.9s
# 793:	learn: 0.0262996	total: 1m 4s	remaining: 16.9s
# 794:	learn: 0.0262795	total: 1m 5s	remaining: 16.8s
# 795:	learn: 0.0262747	total: 1m 5s	remaining: 16.7s
# 796:	learn: 0.0262659	total: 1m 5s	remaining: 16.6s
# 797:	learn: 0.0262317	total: 1m 5s	remaining: 16.5s
# 798:	learn: 0.0262200	total: 1m 5s	remaining: 16.4s
# 799:	learn: 0.0262054	total: 1m 5s	remaining: 16.4s
# 800:	learn: 0.0261702	total: 1m 5s	remaining: 16.3s
# 801:	learn: 0.0261392	total: 1m 5s	remaining: 16.2s
# 802:	learn: 0.0260832	total: 1m 5s	remaining: 16.1s
# 803:	learn: 0.0260510	total: 1m 5s	remaining: 16s
# 804:	learn: 0.0260265	total: 1m 5s	remaining: 16s
# 805:	learn: 0.0260121	total: 1m 5s	remaining: 15.9s
# 806:	learn: 0.0259960	total: 1m 6s	remaining: 15.8s
# 807:	learn: 0.0259476	total: 1m 6s	remaining: 15.7s
# 808:	learn: 0.0259315	total: 1m 6s	remaining: 15.6s
# 809:	learn: 0.0259195	total: 1m 6s	remaining: 15.5s
# 810:	learn: 0.0258822	total: 1m 6s	remaining: 15.5s
# 811:	learn: 0.0258223	total: 1m 6s	remaining: 15.4s
# 812:	learn: 0.0257957	total: 1m 6s	remaining: 15.3s
# 813:	learn: 0.0257420	total: 1m 6s	remaining: 15.2s
# 814:	learn: 0.0256692	total: 1m 6s	remaining: 15.1s
# 815:	learn: 0.0256544	total: 1m 6s	remaining: 15.1s
# 816:	learn: 0.0256388	total: 1m 6s	remaining: 15s
# 817:	learn: 0.0256150	total: 1m 6s	remaining: 14.9s
# 818:	learn: 0.0255616	total: 1m 7s	remaining: 14.8s
# 819:	learn: 0.0255100	total: 1m 7s	remaining: 14.7s
# 820:	learn: 0.0254912	total: 1m 7s	remaining: 14.6s
# 821:	learn: 0.0254632	total: 1m 7s	remaining: 14.6s
# 822:	learn: 0.0254290	total: 1m 7s	remaining: 14.5s
# 823:	learn: 0.0254241	total: 1m 7s	remaining: 14.4s
# 824:	learn: 0.0253930	total: 1m 7s	remaining: 14.3s
# 825:	learn: 0.0253782	total: 1m 7s	remaining: 14.2s
# 826:	learn: 0.0253469	total: 1m 7s	remaining: 14.2s
# 827:	learn: 0.0252885	total: 1m 7s	remaining: 14.1s
# 828:	learn: 0.0252777	total: 1m 7s	remaining: 14s
# 829:	learn: 0.0252610	total: 1m 7s	remaining: 13.9s
# 830:	learn: 0.0252216	total: 1m 8s	remaining: 13.8s
# 831:	learn: 0.0251950	total: 1m 8s	remaining: 13.8s
# 832:	learn: 0.0251692	total: 1m 8s	remaining: 13.7s
# 833:	learn: 0.0251242	total: 1m 8s	remaining: 13.6s
# 834:	learn: 0.0250762	total: 1m 8s	remaining: 13.5s
# 835:	learn: 0.0250590	total: 1m 8s	remaining: 13.4s
# 836:	learn: 0.0250141	total: 1m 8s	remaining: 13.4s
# 837:	learn: 0.0249770	total: 1m 8s	remaining: 13.3s
# 838:	learn: 0.0249108	total: 1m 8s	remaining: 13.2s
# 839:	learn: 0.0248945	total: 1m 8s	remaining: 13.1s
# 840:	learn: 0.0248563	total: 1m 8s	remaining: 13s
# 841:	learn: 0.0248287	total: 1m 9s	remaining: 13s
# 842:	learn: 0.0248039	total: 1m 9s	remaining: 12.9s
# 843:	learn: 0.0247660	total: 1m 9s	remaining: 12.8s
# 844:	learn: 0.0247527	total: 1m 9s	remaining: 12.7s
# 845:	learn: 0.0246978	total: 1m 9s	remaining: 12.6s
# 846:	learn: 0.0246463	total: 1m 9s	remaining: 12.5s
# 847:	learn: 0.0245976	total: 1m 9s	remaining: 12.5s
# 848:	learn: 0.0245626	total: 1m 9s	remaining: 12.4s
# 849:	learn: 0.0245468	total: 1m 9s	remaining: 12.3s
# 850:	learn: 0.0245124	total: 1m 9s	remaining: 12.2s
# 851:	learn: 0.0244644	total: 1m 9s	remaining: 12.1s
# 852:	learn: 0.0244549	total: 1m 9s	remaining: 12.1s
# 853:	learn: 0.0244114	total: 1m 10s	remaining: 12s
# 854:	learn: 0.0243761	total: 1m 10s	remaining: 11.9s
# 855:	learn: 0.0243468	total: 1m 10s	remaining: 11.8s
# 856:	learn: 0.0243140	total: 1m 10s	remaining: 11.7s
# 857:	learn: 0.0242789	total: 1m 10s	remaining: 11.7s
# 858:	learn: 0.0242306	total: 1m 10s	remaining: 11.6s
# 859:	learn: 0.0241782	total: 1m 10s	remaining: 11.5s
# 860:	learn: 0.0241585	total: 1m 10s	remaining: 11.4s
# 861:	learn: 0.0241341	total: 1m 10s	remaining: 11.3s
# 862:	learn: 0.0241094	total: 1m 10s	remaining: 11.2s
# 863:	learn: 0.0240657	total: 1m 10s	remaining: 11.2s
# 864:	learn: 0.0240313	total: 1m 10s	remaining: 11.1s
# 865:	learn: 0.0240264	total: 1m 11s	remaining: 11s
# 866:	learn: 0.0240044	total: 1m 11s	remaining: 10.9s
# 867:	learn: 0.0239570	total: 1m 11s	remaining: 10.8s
# 868:	learn: 0.0239189	total: 1m 11s	remaining: 10.7s
# 869:	learn: 0.0239023	total: 1m 11s	remaining: 10.7s
# 870:	learn: 0.0238782	total: 1m 11s	remaining: 10.6s
# 871:	learn: 0.0238612	total: 1m 11s	remaining: 10.5s
# 872:	learn: 0.0238358	total: 1m 11s	remaining: 10.4s
# 873:	learn: 0.0238024	total: 1m 11s	remaining: 10.3s
# 874:	learn: 0.0237950	total: 1m 11s	remaining: 10.3s
# 875:	learn: 0.0237708	total: 1m 11s	remaining: 10.2s
# 876:	learn: 0.0237533	total: 1m 11s	remaining: 10.1s
# 877:	learn: 0.0237033	total: 1m 12s	remaining: 10s
# 878:	learn: 0.0236836	total: 1m 12s	remaining: 9.93s
# 879:	learn: 0.0236355	total: 1m 12s	remaining: 9.85s
# 880:	learn: 0.0235799	total: 1m 12s	remaining: 9.77s
# 881:	learn: 0.0235626	total: 1m 12s	remaining: 9.69s
# 882:	learn: 0.0235188	total: 1m 12s	remaining: 9.6s
# 883:	learn: 0.0234872	total: 1m 12s	remaining: 9.52s
# 884:	learn: 0.0234468	total: 1m 12s	remaining: 9.44s
# 885:	learn: 0.0234368	total: 1m 12s	remaining: 9.36s
# 886:	learn: 0.0234078	total: 1m 12s	remaining: 9.28s
# 887:	learn: 0.0233492	total: 1m 12s	remaining: 9.2s
# 888:	learn: 0.0232778	total: 1m 12s	remaining: 9.11s
# 889:	learn: 0.0232325	total: 1m 13s	remaining: 9.03s
# 890:	learn: 0.0232108	total: 1m 13s	remaining: 8.95s
# 891:	learn: 0.0231742	total: 1m 13s	remaining: 8.87s
# 892:	learn: 0.0231527	total: 1m 13s	remaining: 8.79s
# 893:	learn: 0.0231342	total: 1m 13s	remaining: 8.7s
# 894:	learn: 0.0231228	total: 1m 13s	remaining: 8.62s
# 895:	learn: 0.0231107	total: 1m 13s	remaining: 8.54s
# 896:	learn: 0.0231002	total: 1m 13s	remaining: 8.45s
# 897:	learn: 0.0230700	total: 1m 13s	remaining: 8.37s
# 898:	learn: 0.0230345	total: 1m 13s	remaining: 8.29s
# 899:	learn: 0.0229919	total: 1m 13s	remaining: 8.21s
# 900:	learn: 0.0229695	total: 1m 13s	remaining: 8.13s
# 901:	learn: 0.0229360	total: 1m 14s	remaining: 8.05s
# 902:	learn: 0.0229074	total: 1m 14s	remaining: 7.96s
# 903:	learn: 0.0228549	total: 1m 14s	remaining: 7.88s
# 904:	learn: 0.0227985	total: 1m 14s	remaining: 7.8s
# 905:	learn: 0.0227895	total: 1m 14s	remaining: 7.72s
# 906:	learn: 0.0227762	total: 1m 14s	remaining: 7.64s
# 907:	learn: 0.0227567	total: 1m 14s	remaining: 7.55s
# 908:	learn: 0.0227279	total: 1m 14s	remaining: 7.48s
# 909:	learn: 0.0227077	total: 1m 14s	remaining: 7.4s
# 910:	learn: 0.0226812	total: 1m 14s	remaining: 7.31s
# 911:	learn: 0.0226553	total: 1m 14s	remaining: 7.23s
# 912:	learn: 0.0226372	total: 1m 15s	remaining: 7.15s
# 913:	learn: 0.0226276	total: 1m 15s	remaining: 7.07s
# 914:	learn: 0.0225999	total: 1m 15s	remaining: 6.98s
# 915:	learn: 0.0225935	total: 1m 15s	remaining: 6.9s
# 916:	learn: 0.0225869	total: 1m 15s	remaining: 6.82s
# 917:	learn: 0.0225686	total: 1m 15s	remaining: 6.74s
# 918:	learn: 0.0225037	total: 1m 15s	remaining: 6.66s
# 919:	learn: 0.0224843	total: 1m 15s	remaining: 6.57s
# 920:	learn: 0.0224282	total: 1m 15s	remaining: 6.49s
# 967:	learn: 0.0213471	total: 1m 19s	remaining: 2.64s
# 968:	learn: 0.0213114	total: 1m 19s	remaining: 2.56s
# 969:	learn: 0.0213030	total: 1m 19s	remaining: 2.47s
# 970:	learn: 0.0212934	total: 1m 20s	remaining: 2.39s
# 971:	learn: 0.0212285	total: 1m 20s	remaining: 2.31s
# 972:	learn: 0.0212153	total: 1m 20s	remaining: 2.23s
# 973:	learn: 0.0211786	total: 1m 20s	remaining: 2.14s
# 974:	learn: 0.0211646	total: 1m 20s	remaining: 2.06s
# 975:	learn: 0.0211477	total: 1m 20s	remaining: 1.98s
# 976:	learn: 0.0211024	total: 1m 20s	remaining: 1.9s
# 977:	learn: 0.0210740	total: 1m 20s	remaining: 1.81s
# 978:	learn: 0.0210617	total: 1m 20s	remaining: 1.73s
# 979:	learn: 0.0210001	total: 1m 20s	remaining: 1.65s
# 980:	learn: 0.0209842	total: 1m 20s	remaining: 1.57s
# 981:	learn: 0.0209680	total: 1m 21s	remaining: 1.49s
# 982:	learn: 0.0209259	total: 1m 21s	remaining: 1.4s
# 983:	learn: 0.0208957	total: 1m 21s	remaining: 1.32s
# 984:	learn: 0.0208513	total: 1m 21s	remaining: 1.24s
# 985:	learn: 0.0208328	total: 1m 21s	remaining: 1.16s
# 986:	learn: 0.0208277	total: 1m 21s	remaining: 1.07s
# 987:	learn: 0.0207955	total: 1m 21s	remaining: 991ms
# 988:	learn: 0.0207676	total: 1m 21s	remaining: 908ms
# 989:	learn: 0.0207173	total: 1m 21s	remaining: 826ms
# 990:	learn: 0.0206996	total: 1m 21s	remaining: 743ms
# 991:	learn: 0.0206551	total: 1m 21s	remaining: 661ms
# 992:	learn: 0.0206089	total: 1m 22s	remaining: 579ms
# 993:	learn: 0.0205611	total: 1m 22s	remaining: 496ms
# 994:	learn: 0.0205524	total: 1m 22s	remaining: 413ms
# 995:	learn: 0.0205328	total: 1m 22s	remaining: 331ms
# 996:	learn: 0.0204977	total: 1m 22s	remaining: 248ms
# 997:	learn: 0.0204831	total: 1m 22s	remaining: 165ms
# 998:	learn: 0.0204535	total: 1m 22s	remaining: 82.7ms
# 999:	learn: 0.0204286	total: 1m 22s	remaining: 0us
# Pipeline(steps=[('catboost',
#                  <catboost.core.CatBoostClassifier object at 0x000001FCC901A670>)])

# %%
### Predicting the test data
y_pred_oot = best_model.predict(X_test)
y_proba_oot = best_model.predict_proba(X_test)[:,1]
roc_auc_oot = roc_auc_score(Y_test, y_proba_oot)
print(f'RoC-AUC: {roc_auc_oot:.3f}')
# Out:
# RoC-AUC: 1.000

# %%
from sklearn import metrics

# %%
cm = metrics.confusion_matrix(Y_test,y_pred_oot, normalize = 'true')
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = cm, display_labels = [False, True])
cm_display.plot()
plt.show()

# %% [markdown]
# ### Shap test

# %%
import shap

explainer = shap.TreeExplainer(best_model[-1])
shap_values = explainer.shap_values(X_test)

# %% [markdown]
# ### Conclusions
#
# We were able to train a model that can identify 36% of the people who became customers following the campaign. Another point is that below are the most relevant pieces of information that contributed to the model's outcome.

# %%
shap.summary_plot(shap_values, X_test).
